# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import folium

from folium.plugins import HeatMap

from google.colab import drive

# %%
pip install meteostat
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from meteostat) (2.2.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from meteostat) (2024.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from meteostat) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)
# Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.8

# %% [markdown]
# ## Data Uploading

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Distributed Data Analysis and Mining/Project/data"

data = pd.read_csv(path + "/df_final_with_weather.csv")
# Out:
# <ipython-input-6-e0b3d7dd456b>:3: DtypeWarning: Columns (31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(path + "/df_final_with_weather.csv")

# %%
data.head()
# Out:
#   Flight_Date Operating_Carrier  Flight_Number Origin_Airport  \
# 0  2018-01-02                AS            857            SAN
# 1  2018-01-04                AS            857            SAN
# 2  2018-01-06                AS            857            SAN
# 3  2018-01-09                AS            857            SAN
# 4  2018-01-11                AS            857            SAN
#
#   Destination_Airport  Scheduled_Departure_Time  Actual_Departure_Time  \
# 0                 LIH                       820                  814.0
# 1                 LIH                       820                  813.0
# 2                 LIH                       850                  847.0
# 3                 LIH                       820                  816.0
# 4                 LIH                       820                  811.0
#
#    Departure_Delay_Minutes  Taxi_Out_Time  Takeoff_Time  ...   city_dest  \
# 0                     -6.0           25.0         839.0  ...  Hanama'ulu
# 1                     -7.0           13.0         826.0  ...  Hanama'ulu
# 2                     -3.0           30.0         917.0  ...  Hanama'ulu
# 3                     -4.0           21.0         837.0  ...  Hanama'ulu
# 4                     -9.0           21.0         832.0  ...  Hanama'ulu
#
#    state_dest  id  distance_km  latitude_orig  longitude_orig  tavg  wspd  \
# 0      Hawaii   0  4300.254683       32.73336     -117.192245  15.8   7.2
# 1      Hawaii   1  4300.254683       32.73336     -117.192245  16.6   5.8
# 2      Hawaii   2  4300.254683       32.73336     -117.192245  16.6   6.8
# 3      Hawaii   3  4300.254683       32.73336     -117.192245  17.1  23.4
# 4      Hawaii   4  4300.254683       32.73336     -117.192245  14.4   5.8
#
#     wdir    pres
# 0  337.0  1019.5
# 1    0.0  1020.2
# 2  344.0  1020.4
# 3  221.0     0.0
# 4    0.0  1022.3
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Define Routes

# %%
unique_routes = data[['latitude_orig', 'longitude_orig', 'latitude_dest', 'longitude_dest']].drop_duplicates()
route_counts = data.groupby(['latitude_orig', 'longitude_orig', 'latitude_dest', 'longitude_dest']).size().reset_index(name = 'count')
unique_airports = data[['Origin_Airport','latitude_orig','longitude_orig']].drop_duplicates()

top_routes = route_counts.nlargest(30, 'count')

# %%
unique_orig_counts = data.groupby(['Origin_Airport', 'latitude_orig', 'longitude_orig']).size().reset_index(name='count')

top_origin = unique_orig_counts.nlargest(30, 'count')

# %%
top_origin.head()
# Out:
#     Origin_Airport  latitude_orig  longitude_orig   count
# 21             ATL      33.637800      -84.429270  390046
# 247            ORD      41.977960      -87.909170  332953
# 92             DFW      32.896520      -97.046524  279298
# 91             DEN      39.860670     -104.685360  235989
# 71             CLT      35.210743      -80.945740  233317

# %%
unique_dest_counts = data.groupby(['Destination_Airport', 'latitude_dest', 'longitude_dest']).size().reset_index(name='count')

top_destinations = unique_dest_counts.nlargest(30, 'count')

top_destinations.head()
# Out:
#     Destination_Airport  latitude_dest  longitude_dest   count
# 21                  ATL      33.637800      -84.429270  390079
# 247                 ORD      41.977960      -87.909170  332942
# 92                  DFW      32.896520      -97.046524  279272
# 91                  DEN      39.860670     -104.685360  236020
# 71                  CLT      35.210743      -80.945740  233309

# %% [markdown]
# ## Main Routes

# %%
# Logarithmic scale for line thickness

min_count = top_routes['count'].min()
max_count = top_routes['count'].max()

# %%
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

for _, row in top_routes.iterrows(): # Iterate over most frequent routes
    origin = (row['latitude_orig'], row['longitude_orig'])
    destination = (row['latitude_dest'], row['longitude_dest'])
    frequency = row['count']  # Obtain route frequency

    folium.PolyLine(
        locations=[origin, destination],
        color='blue',
        weight = 2.5 + 5 * (np.log(frequency) - np.log(min_count)) / (np.log(max_count) - np.log(min_count)),
        opacity=0.7
    ).add_to(m) # Plot a line according to the frequency

    folium.Marker(location=origin, popup="Origin", icon=folium.Icon(color='green')).add_to(m)
    folium.Marker(location=destination, popup="Destination", icon=folium.Icon(color='red')).add_to(m)

m.save("flights_top_routes_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40ff53973567dfc4988ed3ab865e751f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40ff53973567dfc4988ed3ab865e751f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40ff53973567dfc4988ed3ab865e751f = L.map(
#                 &quot;map_40ff53973567dfc4988ed3ab865e751f&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02025475ae78ed24c64c4b0233203b8e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_02025475ae78ed24c64c4b0233203b8e.addTo(map_40ff53973567dfc4988ed3ab865e751f);
#
#
#             var poly_line_97f481779a2b6a73836c7fcde1a8e71d = L.polyline(
#                 [[41.97796, -87.90917], [40.775715, -73.87337]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 7.5}
#             ).addTo(map_40ff53973567dfc4988ed3ab865e751f);
#
#
#             var marker_f71eb5a5265fa5201fafefc5265581d6 = L.marker(
#                 [41.97796, -87.90917],
#                 {}
#             ).addTo(map_40ff53973567dfc4988ed3ab865e751f);
#
#
#             var icon_fddbdee01e9564442f8f3845d1aa0710 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f71eb5a5265fa5201fafefc5265581d6.setIcon(icon_fddbdee01e9564442f8f3845d1aa0710);
#
#
#         var popup_b38871c94f1e8b1a08f73cda3ad6170b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2b281d404fbb29407df625884715d46 = $(`&lt;div id=&quot;html_d2b281d404fbb29407df625884715d46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Origin&lt;/div&gt;`)[0];
#                 popup_b38871c94f1e8b1a08f73cda3ad6170b.setContent(html_d2b281d404fbb29407df625884715d46);
#
#
#
#         marker_f71eb5a5265fa5201fafefc5265581d6.bindPopup(popup_b38871c94f1e8b1a08f73cda3ad6170b)
#         ;
#
#
#
#
#             var marker_acdabe8246824bbbee1476c6a7b6c441 = L.marker(
#                 [40.775715, -73.87337],
#                 {}
#             ).addTo(map_40ff53973567dfc4988ed3ab865e751f);
#
#
#             var icon_c444e1e4b355d967d0545c05c75637b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_acdabe8246824bbbee1476c6a7b6c441.setIcon(icon_c444e1e4b355d967d0545c05c75637b6);
#
#
#         var popup_1c69ad765a1c16fa4db87c9503ff2637 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b671f3bfb577d66e4edfe86d477457a0 = $(`&lt;div id=&quot;html_b671f3bfb577d66e4edfe86d477457a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination&lt;/div&gt;`)[0];
#                 popup_1c69ad765a1c16fa4db87c9503ff2637.setContent(html_b671f3bfb577d66e4edfe86d477457a0);
#
#
#
#         marker_acdabe8246824bbbee1476c6a7b6c441.bindPopup(popup_1c69ad765a1c16fa4db87c9503ff2637)
#         ;
#
#
#
#
#             var poly_line_ea67992411eca7eedda4c86da8838623 = L.polyline(
#                 [[40.775715, -73.87337], [41.97796, -87.90917]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 7.498976936580562}
#             ).addTo(map_40ff53973567dfc4988ed3ab865e751f);
#
#
#             var marker_50c1f3f2ea903b70b71639612367fb88 = L.marker(
#                 [40.775715, -73.87337],
#                 {}
#             ).addTo(map_40ff53973567dfc4988ed3ab865e751f);
#
#
#             var icon_c01f46ca21ebf1

# %% [markdown]
# ## Airports Location

# %%
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

for _, row in unique_airports.iterrows(): # Iterate over most frequent routes
    origin = (row['latitude_orig'], row['longitude_orig'])
    airport = row['Origin_Airport']

    folium.CircleMarker(
        location=origin,
        radius=3,  # Adjust the radius (size) of the origin point
        color = 'blue' ,  # Set the color of the origin point
        fill=True,  # Fill the circle with the color
        fill_color = 'blue',  # Fill the circle with the same color
        fill_opacity=0.6,  # Opacity of the filled color
        popup=airport
        ).add_to(m)

m.save("airports_unique_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90ea731cdaffb7dee9e3aa6a9a504abf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90ea731cdaffb7dee9e3aa6a9a504abf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90ea731cdaffb7dee9e3aa6a9a504abf = L.map(
#                 &quot;map_90ea731cdaffb7dee9e3aa6a9a504abf&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb6a1027ad353b2ba883c4367ebc35a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb6a1027ad353b2ba883c4367ebc35a0.addTo(map_90ea731cdaffb7dee9e3aa6a9a504abf);
#
#
#             var circle_marker_991c2f25a0eb81083bff82317c33a349 = L.circleMarker(
#                 [32.73336, -117.192245],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_90ea731cdaffb7dee9e3aa6a9a504abf);
#
#
#         var popup_17cab13a95cf0e8c0dceb18fcc67e6ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3dac9af77d27e0ee87161e5b10a9daab = $(`&lt;div id=&quot;html_3dac9af77d27e0ee87161e5b10a9daab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SAN&lt;/div&gt;`)[0];
#                 popup_17cab13a95cf0e8c0dceb18fcc67e6ae.setContent(html_3dac9af77d27e0ee87161e5b10a9daab);
#
#
#
#         circle_marker_991c2f25a0eb81083bff82317c33a349.bindPopup(popup_17cab13a95cf0e8c0dceb18fcc67e6ae)
#         ;
#
#
#
#
#             var circle_marker_84c7a6d29af723bb4e3b27a3b14b1eda = L.circleMarker(
#                 [39.86067, -104.68536],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_90ea731cdaffb7dee9e3aa6a9a504abf);
#
#
#         var popup_33070ecc7b101fa40bbd540b9d89db17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8da51551e2f2db5d1ee8062824cff280 = $(`&lt;div id=&quot;html_8da51551e2f2db5d1ee8062824cff280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DEN&lt;/div&gt;`)[0];
#                 popup_33070ecc7b101fa40bbd540b9d89db17.setContent(html_8da51551e2f2db5d1ee8062824cff280);
#
#
#
#         circle_marker_84c7a6d29af723bb4e3b27a3b14b1eda.bindPopup(popup_33070ecc7b101fa40bbd540b9d89db17)
#         ;
#
#
#
#
#             var circle_marker_5353559f90aab597cad74f2222731bc1 = L.circleMarker(
#                 [33.43289, -112.00942],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_90ea731cdaffb7dee9e3aa6a9a504abf);
#
#
#         var popup_a377865b48fc701e1536fe0c9245544d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_971132e5984688c7380ac3b0d2ce57f1 = $(`&lt;div id=&quot;html_971132e5984688c7380ac3b0d2ce57f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PHX&lt;/div&gt;`)[0];
#                 popup_a377865b48fc701e1536fe0c9245544d.setContent(html_971132e5984688c7380ac3b0d2ce57f1);
#
#
#
#         circle_marker_5353559f90aab597cad74f2222731bc1.bindPopup(popup_a377865b48fc701e1536fe0c9245544d)
#         ;
#
#
#
#
#             var circle_marker_0064de2c2fc0b2b6c8a451333a01d207 = L.circleMarker(
#                 [37.62245, -122.38407],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &q

# %% [markdown]
# ## Heat Map

# %%
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

airport_coords = unique_airports[['latitude_orig', 'longitude_orig']].values.tolist()

HeatMap(airport_coords).add_to(m) # Add airport points to HeatMap

m.save("airports_heatmap.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04327db4da1af1ffe99357969e3a6455 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04327db4da1af1ffe99357969e3a6455&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04327db4da1af1ffe99357969e3a6455 = L.map(
#                 &quot;map_04327db4da1af1ffe99357969e3a6455&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ec1f90549653e03e6b459f639816d71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0ec1f90549653e03e6b459f639816d71.addTo(map_04327db4da1af1ffe99357969e3a6455);
#
#
#             var heat_map_2a981ebe98adeb6a90faef4eec702d39 = L.heatLayer(
#                 [[32.73336, -117.192245], [39.86067, -104.68536], [33.43289, -112.00942], [37.62245, -122.38407], [21.320404, -157.91731], [37.363327, -121.92934], [33.94217, -118.421394], [20.895699, -156.43405], [32.89652, -97.046524], [47.447567, -122.308014], [37.722164, -122.21707], [19.743906, -156.0423], [45.58752, -122.59314], [38.80043, -104.70328], [40.915207, -81.439926], [39.997055, -82.89304], [39.87502, -75.235214], [34.895447, -82.21723], [18.4432, -65.99743], [39.0555, -84.66145], [38.853436, -77.04346], [42.94654, -87.897224], [42.876614, -85.53488], [42.2057, -83.352974], [26.072018, -80.15099], [40.272934, -79.40642], [38.952267, -77.45348], [41.068016, -73.708336], [33.6378, -84.42927], [36.0861, -115.16112], [41.72244, -71.42859], [39.457085, -74.570274], [41.301125, -95.88987], [42.960754, -83.74563], [29.9942, -90.264305], [33.563507, -86.75154], [35.436424, -82.54088], [40.795784, -73.0992], [41.940582, -72.68502], [43.12759, -77.66522], [30.49473, -81.69245], [41.40662, -81.851204], [40.64295, -73.77937], [29.533401, -98.469215], [42.362972, -71.013504], [29.647148, -95.276924], [38.171696, -85.735405], [42.930664, -71.43883], [36.89467, -76.20229], [35.88036, -78.78724], [40.491783, -80.23702], [40.689064, -74.17725], [43.64618, -70.314415], [40.790066, -111.9799], [39.30231, -94.72119], [42.9402, -78.73075], [36.11959, -86.68309], [38.749626, -90.37047], [39.179527, -76.66894], [29.984142, -95.332985], [35.046257, -89.9769], [41.97796, -87.90917], [32.845024, -96.84984], [40.276413, -74.81321], [43.113842, -76.111465], [36.10315, -79.943565], [42.74575, -73.80921], [39.716255, -86.29508], [35.210743, -80.94574], [40.775715, -73.87337], [25.79498, -80.28672], [44.878017, -93.220924], [30.19349, -97.66501], [41.785442, -87.75083], [33.305916, -111.65264], [28.775433, -81.24329], [26.919167, -81.99139], [26.53295, -81.758804], [28.412903, -81.30944], [27.909943, -82.68769], [27.979164, -82.53493], [38.687225, -121.59037], [47.620045, -117.542366], [39.498646, -119.77333], [35.80955, -83.99885], [39.813217, -82.9342], [35.384804, -97.60535], [40.67717, -89.69899], [38.034805, -84.60492], [38.65178, -89.85183], [35.389896, -80.71022], [36.275257, -94.29711], [38.04189, -87.529686], [37.239388, -93.396614], [34.054142, -117.59916], [43.569263, -116.22193], [33.674206, -117.86801], [32.120243, -110.936874], [21.972065, -159.33672], [33.815567, -118.15343], [34.20317, -118.35917], [36.19685, -95.88675], [35.03767, -106.61097], [35.23749, -120.64332], [38.510014, -122.78423], [35.437267, -119.05923], [40.976364, -124.10843], [40.509834, -122.29537], [46.916866, -114.0878], [38.51182, -107.89249], [34.427383, -119.84314], [44.12307, -123.213905], [36.776005, -119.71974], [46.26262, -119.11867], [43.142082, -89.337746], [61.181034, -149.9979], [43.60879, -110.73803], [36.58706, -121.84194], [44.25408, -121.14907], [41.534256, -93.65927], [43.503925, -114.29716], [43.415493, -124.24346], [48.310802, -114.25569], [33.830338, -116.50964], [40.48447, -107.22094], [45.78359, -111.15698], [37.627125, -118.84149], [39.219685, -106.864685], [42.4817, -114.4877], [39.63988, -106.91347], [42.372746, -122.87343], [36.473446, -82.40843], [30.49542, -86.5495], [33.68064, -78.92906], [30.472597, -87.18809], [27.395988, -82.55408], [45.8214, -88.11311], [40.979828, -85.18791], [39.90532, -84.220245], [42.491, -76.4587], [42.778072, -84.58586], [32.8993, -80.03947], [41.44772, -90.51147], [41.700726, -86.31348], [43.535797, -84.08285], [44.743492, -85.58421], [41.337093, -75.72257], [41.502052, -74.1212], [40.19321, -76.752945], [46.5, -84.35], [46.34965, -87.38718], [44.772717, -89.66717], [34.636993, -86.76383], [44.472897, -73.15147], [37.50611, -77.3225], [41.889423, -91.7003], [44.47849, -88.14362], [35.032383, -85.201675], [45.569267, -84.79695], [40.850323, -77.84866], [42.160843, -76.89199], [42.230785, -85.55104], [26.685947, -80.09248], [32.12423

# %% [markdown]
# ### Top Airports per Arrivals Volume

# %%
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

for _, row in top_destinations.iterrows():
    origin = (row['latitude_dest'], row['longitude_dest'])
    airport = row['Destination_Airport']
    count = row['count']

    icon_size = min(count / 10, 10)  # Adjust icon size based on count, so size will be proportional to count

    folium.Marker(
        location=origin,
        popup=airport + ", " + str(count),
        icon=folium.Icon(color='green', icon_size=(icon_size, icon_size))
    ).add_to(m) # Iterate over most frequent routes

m.save("airports_unique_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cddc9e79f860b45e59c5a20cb8ef236e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cddc9e79f860b45e59c5a20cb8ef236e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cddc9e79f860b45e59c5a20cb8ef236e = L.map(
#                 &quot;map_cddc9e79f860b45e59c5a20cb8ef236e&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc1c03921038049f78b4ab6c4c08ec15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cc1c03921038049f78b4ab6c4c08ec15.addTo(map_cddc9e79f860b45e59c5a20cb8ef236e);
#
#
#             var marker_2273e02951460373cf48beb21344fce8 = L.marker(
#                 [33.6378, -84.42927],
#                 {}
#             ).addTo(map_cddc9e79f860b45e59c5a20cb8ef236e);
#
#
#             var icon_72bbdbf2c22f0bd94a2b5631f2cdca55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [10, 10], &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2273e02951460373cf48beb21344fce8.setIcon(icon_72bbdbf2c22f0bd94a2b5631f2cdca55);
#
#
#         var popup_f0d91cf869c3c200563d7e33bc0e970e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_764644ae7e926e85e2b779d13ca9f720 = $(`&lt;div id=&quot;html_764644ae7e926e85e2b779d13ca9f720&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATL, 390079&lt;/div&gt;`)[0];
#                 popup_f0d91cf869c3c200563d7e33bc0e970e.setContent(html_764644ae7e926e85e2b779d13ca9f720);
#
#
#
#         marker_2273e02951460373cf48beb21344fce8.bindPopup(popup_f0d91cf869c3c200563d7e33bc0e970e)
#         ;
#
#
#
#
#             var marker_748a0ba3e2f9506f0459ddd251e894f0 = L.marker(
#                 [41.97796, -87.90917],
#                 {}
#             ).addTo(map_cddc9e79f860b45e59c5a20cb8ef236e);
#
#
#             var icon_9673aa536630b416a67442c6f738da7d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [10, 10], &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_748a0ba3e2f9506f0459ddd251e894f0.setIcon(icon_9673aa536630b416a67442c6f738da7d);
#
#
#         var popup_f1069433d45f95aeb0016ad2cd0248b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4461544f1de8684778df756b78c0f261 = $(`&lt;div id=&quot;html_4461544f1de8684778df756b78c0f261&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ORD, 332942&lt;/div&gt;`)[0];
#                 popup_f1069433d45f95aeb0016ad2cd0248b2.setContent(html_4461544f1de8684778df756b78c0f261);
#
#
#
#         marker_748a0ba3e2f9506f0459ddd251e894f0.bindPopup(popup_f1069433d45f95aeb0016ad2cd0248b2)
#         ;
#
#
#
#
#             var marker_c75438e7621d9d6a962526bd0d33034a = L.marker(
#                 [32.89652, -97.046524],
#                 {}
#             ).addTo(map_cddc9e79f860b45e59c5a20cb8ef236e);
#
#
#             var icon_8dd055507d2ce1db0b83859e60c861ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [10, 10], &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c75438e7621d9d6a962526bd0d33034a.setIcon(icon_8dd055507d2ce1db0b83859e60c861ce);
#
#
#         var popup_09ba572b8705402867ccd921b66a7966 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50da61e028e4e31a5044dca17fa48683 = $(`&lt;div id=&quot;html_50da61e028e4e31a5044dca17fa48683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DFW, 279272&lt;/div&gt;`)[0];
#                 popup_09ba572b8705402867ccd921b66a7966.setContent(html_50da61e028e4e31a5044dca17fa48683);
#
#
#
#         marker_c75438e7621d9d6a962526bd0d33034a.bindPopup(popup_09ba572b8705402867ccd921b66a7966)
#         ;
#
#
#
#
#             var marker_c2ac4024ad78e18ac01c451bc005a4fc = L.marker(
#                 [39.86067, -104.68536],
#                 {}
#             ).addTo(map_cddc9e79f860b45e59c5a20cb8ef236e);
#
#
#             var icon_695f70be324c850e3f048bf780a253c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &

# %% [markdown]
# ### Routes from the most Popular Airport

# %%
atlanta_routes = data[data['Destination_Airport'] == "ATL"]
atlanta_routes_counts = atlanta_routes.groupby(['latitude_orig', 'longitude_orig', 'latitude_dest', 'longitude_dest']).size().reset_index(name='count')

# %%
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

for _, row in atlanta_routes_counts.iterrows():
    origin = (row['latitude_orig'], row['longitude_orig'])
    destination = (row['latitude_dest'], row['longitude_dest'])
    frequency = row['count']  # Obtain route frequency

    folium.PolyLine(     # Plot a line according to the frequency
        locations=[origin, destination],
        color='gray',
        weight = 2.5 + 5 * (np.log(frequency) - np.log(min_count)) / (np.log(max_count) - np.log(min_count)),
        opacity=0.7
    ).add_to(m) # Iterate over most frequent routes

    origin_color = 'green'  # Color for origin point
    destination_color = 'red'  # Color for destination point
    origin_size = 6  # Radius of the origin point
    destination_size = 8  # Radius of the destination point

    folium.CircleMarker(
        location=origin,
        radius=origin_size,  # Adjust the radius (size) of the origin point
        color=origin_color,  # Set the color of the origin point
        fill=True,  # Fill the circle with the color
        fill_color=origin_color,  # Fill the circle with the same color
        fill_opacity=0.6,  # Opacity of the filled color
        popup="Origin"
        ).add_to(m) # Add points using CircleMarker for origin

    folium.CircleMarker(
        location=destination,
        radius=destination_size,  # Adjust the radius (size) of the destination point
        color=destination_color,  # Set the color of the destination point
        fill=True,  # Fill the circle with the color
        fill_color=destination_color,  # Fill the circle with the same color
        fill_opacity=0.6,  # Opacity of the filled color
        popup="Destination"
        ).add_to(m) # Add points using CircleMarker for destination

m.save("atlanta_route_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf7e5973de64d7c05f3e61aa940f57be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf7e5973de64d7c05f3e61aa940f57be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf7e5973de64d7c05f3e61aa940f57be = L.map(
#                 &quot;map_bf7e5973de64d7c05f3e61aa940f57be&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_605d30b391c04b0015721a3dd6e0a4be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_605d30b391c04b0015721a3dd6e0a4be.addTo(map_bf7e5973de64d7c05f3e61aa940f57be);
#
#
#             var poly_line_b39b62d071b367c579a0a39f94f98942 = L.polyline(
#                 [[17.699978, -64.80592], [33.6378, -84.42927]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: -33.456257831357355}
#             ).addTo(map_bf7e5973de64d7c05f3e61aa940f57be);
#
#
#             var circle_marker_4ac96cca3b5af1c1d4b56864303e5356 = L.circleMarker(
#                 [17.699978, -64.80592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bf7e5973de64d7c05f3e61aa940f57be);
#
#
#         var popup_80d867b3f147d4bfb344eecb2dbf360e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef1d603c4a6a373fab9374fe2275c9f8 = $(`&lt;div id=&quot;html_ef1d603c4a6a373fab9374fe2275c9f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Origin&lt;/div&gt;`)[0];
#                 popup_80d867b3f147d4bfb344eecb2dbf360e.setContent(html_ef1d603c4a6a373fab9374fe2275c9f8);
#
#
#
#         circle_marker_4ac96cca3b5af1c1d4b56864303e5356.bindPopup(popup_80d867b3f147d4bfb344eecb2dbf360e)
#         ;
#
#
#
#
#             var circle_marker_1114f5dd4bb1046f72ff545497ebfb71 = L.circleMarker(
#                 [33.6378, -84.42927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bf7e5973de64d7c05f3e61aa940f57be);
#
#
#         var popup_01dbb29515530c75de15140d86cba35c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_051f95aa09ffa66babf7e1246ab8ecd7 = $(`&lt;div id=&quot;html_051f95aa09ffa66babf7e1246ab8ecd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Destination&lt;/div&gt;`)[0];
#                 popup_01dbb29515530c75de15140d86cba35c.setContent(html_051f95aa09ffa66babf7e1246ab8ecd7);
#
#
#
#         circle_marker_1114f5dd4bb1046f72ff545497ebfb71.bindPopup(popup_01dbb29515530c75de15140d86cba35c)
#         ;
#
#
#
#
#             var poly_line_a634522d791ccac6a38e8e572fe2af3f = L.polyline(
#                 [[18.334673, -64.97017], [33.6378, -84.42927]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: -21.17154807826222}
#             ).addTo(map_bf7e5973de64d7c05f3e61aa940f57be);
#
#
#             var circle_marker_83e41d00398e8cc238753332948a9107 = L.circleMarker(
#                 [18.334673, -64.97017],
#                 {&quot;bubblingMouseEvents&quot;:
